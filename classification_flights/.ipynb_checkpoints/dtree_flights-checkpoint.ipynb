# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv(r"C:\Users\Administrator\Desktop\datasets\business\939775908_T_ONTIME_REPORTING.csv")

# %%
print(df.columns)
print("\n")
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(df.head())
# Out:
# Index(['YEAR', 'QUARTER', 'MONTH', 'DAY_OF_MONTH', 'FL_DATE',
#        'OP_UNIQUE_CARRIER', 'ORIGIN', 'DEST', 'CRS_DEP_TIME', 'DEP_TIME',
#        'DEP_DELAY', 'DEP_DEL15', 'DEP_DELAY_GROUP', 'TAXI_OUT', 'WHEELS_OFF',
#        'WHEELS_ON', 'TAXI_IN', 'CRS_ARR_TIME', 'ARR_TIME', 'ARR_DELAY',
#        'ARR_DEL15', 'CANCELLED', 'CANCELLATION_CODE', 'DIVERTED',
#        'CRS_ELAPSED_TIME', 'ACTUAL_ELAPSED_TIME', 'AIR_TIME', 'FLIGHTS',
#        'DISTANCE', 'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY',
#        'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY', 'DIV_AIRPORT_LANDINGS',
#        'Unnamed: 35'],
#       dtype='object')
#
#
#    YEAR  QUARTER  MONTH  DAY_OF_MONTH     FL_DATE OP_UNIQUE_CARRIER ORIGIN  \
# 0  2018        1      1            27  2018-01-27                UA    FLL
# 1  2018        1      1            27  2018-01-27                UA    SEA
# 2  2018        1      1            27  2018-01-27                UA    DCA
# 3  2018        1      1            27  2018-01-27                UA    LAX
# 4  2018        1      1            27  2018-01-27                UA    JAX
#
#   DEST  CRS_DEP_TIME  DEP_TIME  DEP_DELAY  DEP_DEL15  DEP_DELAY_GROUP  \
# 0  IAH           615     602.0      -13.0        0.0             -1.0
# 1  SFO           618     614.0       -4.0        0.0             -1.0
# 2  IAH           830     828.0       -2.0        0.0             -1.0
# 3  ORD           650     641.0       -9.0        0.0             -1.0
# 4  EWR          1824    1810.0      -14.0        0.0             -1.0
#
#    TAXI_OUT  WHEELS_OFF  WHEELS_ON  TAXI_IN  CRS_ARR_TIME  ARR_TIME  \
# 0      19.0       621.0      749.0      7.0           808     756.0
# 1      16.0       630.0      808.0      5.0           831     813.0
# 2      17.0       845.0     1055.0     13.0          1107    1108.0
# 3      17.0       658.0     1230.0     12.0          1250    1242.0
# 4      11.0      1821.0     2013.0      8.0          2045    2021.0
#
#    ARR_DELAY  ARR_DEL15  CANCELLED CANCELLATION_CODE  DIVERTED  \
# 0      -12.0        0.0        0.0               NaN       0.0
# 1      -18.0        0.0        0.0               NaN       0.0
# 2        1.0        0.0        0.0               NaN       0.0
# 3       -8.0        0.0        0.0               NaN       0.0
# 4      -24.0        0.0        0.0               NaN       0.0
#
#    CRS_ELAPSED_TIME  ACTUAL_ELAPSED_TIME  AIR_TIME  FLIGHTS  DISTANCE  \
# 0             173.0                174.0     148.0      1.0     966.0
# 1             133.0                119.0      98.0      1.0     679.0
# 2             217.0                220.0     190.0      1.0    1208.0
# 3             240.0                241.0     212.0      1.0    1744.0
# 4             141.0                131.0     112.0      1.0     820.0
#
#    CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  SECURITY_DELAY  \
# 0            NaN            NaN        NaN             NaN
# 1            NaN            NaN        NaN             NaN
# 2            NaN            NaN        NaN             NaN
# 3            NaN            NaN        NaN             NaN
# 4            NaN            NaN        NaN             NaN
#
#    LATE_AIRCRAFT_DELAY  DIV_AIRPORT_LANDINGS  Unnamed: 35
# 0                  NaN                     0          NaN
# 1                  NaN                     0          NaN
# 2                  NaN                     0          NaN
# 3                  NaN                     0          NaN
# 4                  NaN                     0          NaN

# %%
df = df.drop(['ARR_DEL15', 'DEP_DEL15', 'DEP_DELAY_GROUP', 'TAXI_OUT', 'WHEELS_OFF', 'ORIGIN','WHEELS_ON', 'YEAR', 'TAXI_IN', 'TAXI_OUT', 'CRS_ARR_TIME', 'ARR_TIME', 'DIVERTED', 'CRS_DEP_TIME', 'QUARTER', 'DEP_TIME', 'DIV_AIRPORT_LANDINGS', 'DEST', 'OP_UNIQUE_CARRIER', 'CANCELLATION_CODE'], 1)
print("======")
print(df.info())
print("======")
print(df.isnull().any())
print("======")
print(df.columns)
# Out:
# ======
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 570118 entries, 0 to 570117
# Data columns (total 17 columns):
# MONTH                  570118 non-null int64
# DAY_OF_MONTH           570118 non-null int64
# FL_DATE                570118 non-null object
# DEP_DELAY              552795 non-null float64
# ARR_DELAY              551498 non-null float64
# CANCELLED              570118 non-null float64
# CRS_ELAPSED_TIME       570118 non-null float64
# ACTUAL_ELAPSED_TIME    551700 non-null float64
# AIR_TIME               551700 non-null float64
# FLIGHTS                570118 non-null float64
# DISTANCE               570118 non-null float64
# CARRIER_DELAY          97760 non-null float64
# WEATHER_DELAY          97760 non-null float64
# NAS_DELAY              97760 non-null float64
# SECURITY_DELAY         97760 non-null float64
# LATE_AIRCRAFT_DELAY    97760 non-null float64
# Unnamed: 35            0 non-null float64
# dtypes: float64(14), int64(2), object(1)
# memory usage: 73.9+ MB
# None
# ======
# MONTH                  False
# DAY_OF_MONTH           False
# FL_DATE                False
# DEP_DELAY               True
# ARR_DELAY               True
# CANCELLED              False
# CRS_ELAPSED_TIME       False
# ACTUAL_ELAPSED_TIME     True
# AIR_TIME                True
# FLIGHTS                False
# DISTANCE               False
# CARRIER_DELAY           True
# WEATHER_DELAY           True
# NAS_DELAY               True
# SECURITY_DELAY          True
# LATE_AIRCRAFT_DELAY     True
# Unnamed: 35             True
# dtype: bool
# ======
# Index(['MONTH', 'DAY_OF_MONTH', 'FL_DATE', 'DEP_DELAY', 'ARR_DELAY',
#        'CANCELLED', 'CRS_ELAPSED_TIME', 'ACTUAL_ELAPSED_TIME', 'AIR_TIME',
#        'FLIGHTS', 'DISTANCE', 'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY',
#        'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY', 'Unnamed: 35'],
#       dtype='object')

# %%
df['FL_DATE'] = pd.to_datetime(df['FL_DATE'])
df = df.set_index('FL_DATE')
df = df.sort_values(by='FL_DATE')
df = df.dropna(how='all', axis='columns')
df = df.fillna(0)
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(df.head())
# Out:
#             MONTH  DAY_OF_MONTH  DEP_DELAY  ARR_DELAY  CANCELLED  \
# FL_DATE
# 2018-01-01      1             1        0.0       -7.0        0.0
# 2018-01-01      1             1       75.0       35.0        0.0
# 2018-01-01      1             1       50.0       31.0        0.0
# 2018-01-01      1             1        1.0        5.0        0.0
# 2018-01-01      1             1      219.0      236.0        0.0
#
#             CRS_ELAPSED_TIME  ACTUAL_ELAPSED_TIME  AIR_TIME  FLIGHTS  \
# FL_DATE
# 2018-01-01             141.0                134.0      99.0      1.0
# 2018-01-01             290.0                250.0     229.0      1.0
# 2018-01-01             280.0                261.0     246.0      1.0
# 2018-01-01             225.0                229.0     190.0      1.0
# 2018-01-01             125.0                142.0      91.0      1.0
#
#             DISTANCE  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  SECURITY_DELAY  \
# FL_DATE
# 2018-01-01     708.0            0.0            0.0        0.0             0.0
# 2018-01-01    1750.0           35.0            0.0        0.0             0.0
# 2018-01-01    1750.0           31.0            0.0        0.0             0.0
# 2018-01-01    1258.0            0.0            0.0        0.0             0.0
# 2018-01-01     725.0            0.0            0.0       17.0             0.0
#
#             LATE_AIRCRAFT_DELAY
# FL_DATE
# 2018-01-01                  0.0
# 2018-01-01                  0.0
# 2018-01-01                  0.0
# 2018-01-01                  0.0
# 2018-01-01                219.0

# %%
corr = df.corr()
plt.subplots(figsize=(14,14))
sns.heatmap(corr, annot=True)
plt.show()

# %%
# CANCELLATION_CODE = pd.get_dummies(df.CANCELLATION_CODE).iloc[:,1:]
# OP_UNIQUE_CARRIER = pd.get_dummies(df.OP_UNIQUE_CARRIER).iloc[:,1:]
# ORIGIN = pd.get_dummies(df.ORIGIN).iloc[:,1:]
# df = pd.concat([df, OP_UNIQUE_CARRIER, ORIGIN, CANCELLATION_CODE], 1)
# df = df.drop(['OP_UNIQUE_CARRIER', 'ORIGIN', 'CANCELLATION_CODE'],1)

# %%
print(df.shape)
# Out:
# (570118, 15)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, AdaBoostClassifier
from timeit import default_timer as timer

# %%
X = df.drop('CANCELLED', 1)
y = df['CANCELLED']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

regressors = [['DecTree :', DecisionTreeRegressor()],
              ['RandFor :', RandomForestRegressor()]]

# %%
print("\n====== RMSE ======")
for name,regressor in regressors:
    start = timer()
    regressor = regressor
    regressor.fit(X_train, y_train)
    prediction = regressor.predict(X_test)
    rmse = np.sqrt(mean_squared_error(y_test, prediction))
    end = timer()
    time = end - start
    print(name, "% .3f" % rmse)
    print("% .3f" % time,"s")
# Out:
# ====== RMSE ======
# DecTree :  0.033
#  0.228 s
# RandFor :  0.025
#  1.649 s

# %%
print("\n====== R^2 ======")
r2_result = []
for name,regressor in regressors:
    score = regressor.score(X_test, y_test)
    r2_result.append([regressor, score])
    print(name, "% .3f" % score)
# Out:
# ====== R^2 ======
# DecTree :  0.964
# RandFor :  0.979

# %%
regressor = DecisionTreeRegressor()
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)

# %%
importances = regressor.feature_importances_
feature_importances = pd.DataFrame(regressor.feature_importances_,
                                   index = df.columns[:14],
                                   columns=['importance']).sort_values('importance',                     
                                   ascending=False)

print("====== Importance ======")
print(feature_importances)
# Out:
# ====== Importance ======
#                      importance
# CRS_ELAPSED_TIME       0.930113
# DEP_DELAY              0.055217
# FLIGHTS                0.006899
# CANCELLED              0.004425
# DAY_OF_MONTH           0.003346
# MONTH                  0.000000
# ARR_DELAY              0.000000
# ACTUAL_ELAPSED_TIME    0.000000
# AIR_TIME               0.000000
# DISTANCE               0.000000
# CARRIER_DELAY          0.000000
# WEATHER_DELAY          0.000000
# NAS_DELAY              0.000000
# SECURITY_DELAY         0.000000

# %%
cm = confusion_matrix(y_test, y_pred, labels=[1, 0])
cm_df = pd.DataFrame(cm,
                     index = ['1', '0'], 
                     columns = ['1', '0'])

# %%
ax = sns.heatmap(cm_df, fmt='d', cmap="Blues", cbar=False,  annot=True)

plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title('Confusion Matrix')
plt.show()
